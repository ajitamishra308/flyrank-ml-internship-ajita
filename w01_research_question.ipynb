# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitamishra308/flyrank-ml-internship-ajita/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## My Lane: Search Ranking and Content Refresh

I chose the Search Ranking and Content Refresh lane because search engines need to identify which pages should be updated first. The goal of this project is to use machine learning to support content refresh decisions based on page performance and search signals. This can help improve user experience by prioritizing pages that are more likely to decline or need updates.
"""))
# Out:
# ## My Lane: Search Ranking and Content Refresh
#
# I chose the Search Ranking and Content Refresh lane because search engines need to identify which pages should be updated first. The goal of this project is to use machine learning to support content refresh decisions based on page performance and search signals. This can help improve user experience by prioritizing pages that are more likely to decline or need updates.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
display(Markdown("""
## Research Question

**Decision:** Which webpages should be refreshed first?

**Action:** The SEO or content team can update the highest-priority pages before their performance drops further.

**Cost of a wrong recommendation:** If the wrong pages are refreshed, time and resources are wasted while important declining pages continue to lose traffic.

**Why ML?** There are thousands of pages and many ranking signals. Machine learning can learn patterns from historical data and provide decision support that is more effective than simple hand-written rules.
"""))
# Out:
# ## Research Question
#
# **Decision:** Which webpages should be refreshed first?
#
# **Action:** The SEO or content team can update the highest-priority pages before their performance drops further.
#
# **Cost of a wrong recommendation:** If the wrong pages are refreshed, time and resources are wasted while important declining pages continue to lose traffic.
#
# **Why ML?** There are thousands of pages and many ranking signals. Machine learning can learn patterns from historical data and provide decision support that is more effective than simple hand-written rules.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/ajitamishra308/flyrank-ml-internship-ajita.git
# %cd flyrank-ml-internship-ajita
# Out:
# Cloning into 'flyrank-ml-internship-ajita'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 97 (delta 19), reused 81 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (97/97), 1.83 MiB | 6.64 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# /content/flyrank-ml-internship-ajita/flyrank-ml-internship-ajita

# %%
import os
print(os.getcwd())
# Out:
# /content/flyrank-ml-internship-ajita/flyrank-ml-internship-ajita

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

corr = df["search_volume"].corr(df["impressions_90d"])
print("Search Volume vs Impressions Correlation:", round(corr, 3))

wc = df.groupby("trend_direction")["word_count"].median()
print("\nMedian Word Count")
print(wc)
# Out:
# Dataset Shape: (30000, 44)
# Rows: 30000
# Columns: 44
# Search Volume vs Impressions Correlation: 0.001
#
# Median Word Count
# trend_direction
# down      2909.0
# flat      2698.5
# new       2239.0
# stable    2912.5
# up        2847.5
# Name: word_count, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("""
### What I can claim

- The results are based on observed patterns in the starter dataset.
- This work can help identify pages that may need a content refresh.
- The findings are directional and can support decision-making.

### What I cannot claim

- This analysis does not prove cause and effect.
- It cannot predict Google's ranking algorithm.
- The recommendations should be reviewed before taking any final action.
""")
# Out:
# ### What I can claim
#
# - The results are based on observed patterns in the starter dataset.
# - This work can help identify pages that may need a content refresh.
# - The findings are directional and can support decision-making.
#
# ### What I cannot claim
#
# - This analysis does not prove cause and effect.
# - It cannot predict Google's ranking algorithm.
# - The recommendations should be reviewed before taking any final action.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
