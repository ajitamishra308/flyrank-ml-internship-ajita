# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitamishra308/flyrank-ml-internship-ajita/blob/main/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# 1. My lane as an ML task

task_type = "Ranking"

print("Task Type:", task_type)
print("Reason: The model ranks search results so the most relevant content appears first.")
# Out:
# Task Type: Ranking
# Reason: The model ranks search results so the most relevant content appears first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# 2. Target or proxy

target = "Relevance score of a search result"

print("Target:", target)
print("Label Source: Observed user behavior (clicks, engagement, relevance feedback).")
# Out:
# Target: Relevance score of a search result
# Label Source: Observed user behavior (clicks, engagement, relevance feedback).

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# 3. Success metric

success_metric = "NDCG (Normalized Discounted Cumulative Gain)"

print("Success Metric:", success_metric)
print("Reason: NDCG measures how well the most relevant search results are ranked at the top.")
# Out:
# Success Metric: NDCG (Normalized Discounted Cumulative Gain)
# Reason: NDCG measures how well the most relevant search results are ranked at the top.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# 4. The unit of analysis

import pandas as pd

data = {
    "query": ["AI internship", "Machine Learning", "Python course"],
    "document": ["Resume Tips", "ML Basics", "Python Tutorial"],
    "relevance_score": [3, 2, 1]
}

df = pd.DataFrame(data)

print("One row = One search result for a user query")
df
# Out:
# One row = One search result for a user query
#               query         document  relevance_score
# 0     AI internship      Resume Tips                3
# 1  Machine Learning        ML Basics                2
# 2     Python course  Python Tutorial                1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# 5. Why ML beats a fixed rule

print("Why ML?")
print("Search relevance depends on many factors such as user intent, content quality, and behavior.")
print("A fixed rule cannot capture these complex patterns, but ML can learn them from data.")
# Out:
# Why ML?
# Search relevance depends on many factors such as user intent, content quality, and behavior.
# A fixed rule cannot capture these complex patterns, but ML can learn them from data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
